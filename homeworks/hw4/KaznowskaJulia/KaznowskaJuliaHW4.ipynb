# %% [markdown]
# ## Praca domowa 4

# %% [markdown]
# #### Autor: Julia Kaznowska

# %% [markdown]
# ### Zadanie 1 (1.5 pkt)

# %% [markdown]
# Używając funkcji z pakietu `numpy` oraz `pandas` odpowiedz na poniższe pytania dotyczące zbioru danych o grach.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("https://raw.githubusercontent.com/R-Ladies-Warsaw/PoweR/master/Cz%C4%99%C5%9B%C4%87%202%20-%20Formatowanie%20danych/Python/data/vgsales.csv",
                delimiter = ",").dropna().reset_index(drop = True)

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# a) Wybierz gry, które zostały wydane po 2015 roku przez Nintendo oraz ich sprzedaż w Ameryce była niższa niż w Europie.

# %%
df.loc[(df.Year > 2015) & (df.Publisher == "Nintendo") & (df.NA_Sales < df.EU_Sales)]
# Out:
#         Rank                                         Name Platform    Year  \
# 4199    4263  Mario & Sonic at the Rio 2016 Olympic Games      3DS  2016.0
# 6477    6590  Mario & Sonic at the Rio 2016 Olympic Games     WiiU  2016.0
# 14703  14971                               Teddy Together      3DS  2016.0
#
#             Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 4199       Action  Nintendo      0.04      0.16      0.24         0.01
# 6477       Action  Nintendo      0.03      0.11      0.10         0.01
# 14703  Simulation  Nintendo      0.00      0.02      0.00         0.00
#
#        Global_Sales
# 4199           0.46
# 6477           0.26
# 14703          0.02

# %% [markdown]
# b) Jak rodzaj gry zarobił najwięcej w roku 2010?

# %%
best = df.loc[df.Year == 2010].groupby("Genre").Global_Sales.agg("sum").reset_index()
best.sort_values(by = 'Global_Sales', ascending = False).iloc[0,0]
# Out:
# 'Action'

# %% [markdown]
# c) Jakie typy gier sprzedają się średnio lepiej w Japonii niż w Europie? Jakie to typy gier i jaka jest ta wartość średnia. Wynikiem powinna być tabelka posortowana względem średnich. Nazwij kolumny `Typ Gry` i `Średnia sprzedaż w Japonii`.

# %%
jap = df.groupby("Genre").agg({"EU_Sales" : "mean", "JP_Sales" : "mean"}).reset_index()
jap.loc[jap.EU_Sales < jap.JP_Sales].sort_values(by = 'JP_Sales').iloc[:, [0,2]]\
.rename(columns = {"Genre":"Typ gry", "JP_Sales":"Średnia sprzedaż w Japonii"})
# Out:
#          Typ gry  Średnia sprzedaż w Japonii
# 11      Strategy                    0.073284
# 5         Puzzle                    0.099439
# 7   Role-Playing                    0.238293

# %% [markdown]
# ### Zadanie 2 (3.5 pkt)

# %% [markdown]
# Wykorzystując narzędzie do wizualizacji w Pythonie (matplotlib, seaborn) należy poprawić wykres, który był rozwiązaniem pracy domowej 2 (najlepiej poprawić swoją pracę domową, ale można też cudzą).
#
# Rozwiązanie powinno zawierać:
#
# 1) oryginalny wykres wraz ze źródłem
#
# 2) wykres w ggplot2 wraz z linkiem do pracy domowej w której się on pojawił (kod nie jest potrzebny)
#
# 3) poprawiony wykres z punktu 2) w Pythonie
#
# 4) uzasadnienie, czemu wykres w Pythonie jest lepszy od dwóch pozostałych.

# %% [markdown]
# ### Oryginalny wykres:
# ![Oryginalny_wykres.png](attachment:Oryginalny_wykres.png)
# ##### Źródło: https://www.reddit.com/r/dataisugly/comments/qh0tnn/this_caught_my_eye_in_my_school/

# %% [markdown]
# ### Poprawiany wykres:
# ![Poprawiany_wykres.png](attachment:Poprawiany_wykres.png)
# ##### Źródło: https://github.com/mini-pw/2022Z-DataVisualizationTechniques/tree/main/homeworks/hw2/RoguskiMikolaj

# %% [markdown]
# ### Mój wykres:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = ["Other", "Ontario", "BC", "Quebec"]
y = [750, 1850, 5150, 8750]

# %%
fig, ax = plt.subplots() 
ax.barh(x, y)
ax.set_title('Employees in the video games industry')
ax.set_xlabel('Number of employees')
ax.set_ylabel('Province')
hbars = ax.barh(np.arange(len(x)), y, color = "#2b8cbe")
ax.bar_label(hbars)
ax.set_xlim(right=9900)
# Out:
# (0.0, 9900.0)

# %% [markdown]
# ### Uzasadnienie:
# Postanowiłam poprawić wykres Mikołaja tak, aby był stworzony z używaniem "dobrych praktyk" przedstawiania wykresów. Zmieniłam pozycję słupków tak, aby była na osi Y, ponieważ na osi X są zazwyczaj przedstawiane dane według czasu. Użyłam tylko jednego koloru słupków, ponieważ używanie wielu kolorów nie jest potrzebne  i dezorientuje odbiorcę.
