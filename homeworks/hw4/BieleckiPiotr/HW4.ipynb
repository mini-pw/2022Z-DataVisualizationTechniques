# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/R-Ladies-Warsaw/PoweR/master/Cz%C4%99%C5%9B%C4%87%202%20-%20Formatowanie%20danych/Python/data/vgsales.csv",
                delimiter = ",").dropna().reset_index(drop = True)

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16286  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16287  16597                     Men in Black II: Alien Escape       GC
# 16288  16598  SCORE International Baja 1000: The Official Game      PS2
# 16289  16599                                        Know How 2       DS
# 16290  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# a) Wybierz gry, które zostały wydane po 2015 roku przez Nintendo oraz ich sprzedaż w Ameryce była niższa niż w Europie.
df.loc[(df.Year > 2015) & (df.Publisher == "Nintendo") & (df.NA_Sales < df.EU_Sales)]
# Out:
#         Rank                                         Name Platform    Year  \
# 4199    4263  Mario & Sonic at the Rio 2016 Olympic Games      3DS  2016.0
# 6477    6590  Mario & Sonic at the Rio 2016 Olympic Games     WiiU  2016.0
# 14703  14971                               Teddy Together      3DS  2016.0
#
#             Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 4199       Action  Nintendo      0.04      0.16      0.24         0.01
# 6477       Action  Nintendo      0.03      0.11      0.10         0.01
# 14703  Simulation  Nintendo      0.00      0.02      0.00         0.00
#
#        Global_Sales
# 4199           0.46
# 6477           0.26
# 14703          0.02

# %%
# b) Jak rodzaj gry zarobił najwięcej w roku 2010?
tmp = df.loc[(df.Year == 2010)].groupby("Genre").sum().sort_values(ascending = False, by = "Global_Sales")
tmp.drop('Rank', axis = 'columns', inplace = True)
tmp.drop('Year', axis = 'columns', inplace = True)
tmp.head(1)
# Out:
#         NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action     60.32     35.75      8.58        12.85        117.64

# %%
#c) Jakie typy gier sprzedają się średnio lepiej w Japonii niż w Europie? Jakie to typy gier i jaka jest ta wartość średnia.
#Wynikiem powinna być tabelka posortowana względem średnich. Nazwij kolumny Typ Gry i Średnia sprzedaż w Japonii.
tmp = df.rename(columns = {'Genre' : 'Typ Gry'})
tmp = tmp.groupby("Typ Gry").agg("mean")
tmp2 = tmp.loc[tmp.JP_Sales > tmp.EU_Sales]
tmp2[['JP_Sales']].sort_values('JP_Sales', ascending = False).rename(columns = {'JP_Sales' : 'Średnia sprzedaż w Japonii'})
# Out:
#               Średnia sprzedaż w Japonii
# Typ Gry
# Role-Playing                    0.238293
# Puzzle                          0.099439
# Strategy                        0.073284
